# %%
import pandas as pd
import numpy as np
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames=[]
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1001349.yaml',
#  'data\\1001351.yaml',
#  'data\\1001353.yaml',
#  'data\\1004729.yaml',
#  'data\\1007655.yaml']

# %%
final_df=pd.DataFrame()
counter=1
for file in tqdm(filenames):
    with open(file,'r') as f:
        df=pd.json_normalize(safe_load(f))
        df['match_id']=counter
        final_df=final_df.append(df)
        counter+=1
final_df
# Out:
#   0%|          | 0/1433 [00:00<?, ?it/s]C:\Users\Riyal_Rock\AppData\Local\Temp\ipykernel_3944\2778075348.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(df)
#   0%|          | 1/1433 [00:01<28:28,  1.19s/it]C:\Users\Riyal_Rock\AppData\Local\Temp\ipykernel_3944\2778075348.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(df)
#   0%|          | 2/1433 [00:01<15:56,  1.50it/s]C:\Users\Riyal_Rock\AppData\Local\Temp\ipykernel_3944\2778075348.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(df)
# ...

# %%
final_df.head(2)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 0   2017-02-19              2  [2017-02-19]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                      5.0           Sri Lanka          20  ...
# 0                      2.0           Sri Lanka          20  ...
#
#   info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0                  NaN                    NaN                NaN
# 0                  NaN                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# ...

# %%
backup=final_df.copy()

# %%
final_df.drop(columns=["info.outcome.by.runs","info.match_type_number","info.neutral_venue","info.outcome.method","info.outcome.result","info.outcome.eliminator","info.supersubs.New Zealand","info.supersubs.South Africa","info.bowl_out","info.outcome.bowl_out","meta.data_version","meta.created","meta.revision"],inplace=True)

# %%
final_df.head()
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
#
#   info.gender info.match_type  info.outcome.by.wickets info.outcome.winner  \
# 0        male             T20                      5.0           Sri Lanka
# 0        male             T20                      2.0           Sri Lanka
# 0        male             T20                      NaN           Australia
# 0        male             T20                      NaN           Hong Kong
# 0        male             T20                      NaN            Zimbabwe
#
#    info.overs info.player_of_match              info.teams info.toss.decision  \
# ...

# %%
final_df.to_csv('final_df.csv',index=False)

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df=final_df[final_df['info.gender']=='male']

# %%
final_df.drop(columns=['info.gender'],inplace=True)

# %%
final_df.head()
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 0             T20                      2.0           Sri Lanka          20
# 0             T20                      NaN           Australia          20
# 0             T20                      NaN           Hong Kong          20
# 0             T20                      NaN            Zimbabwe          20
#
#   info.player_of_match              info.teams info.toss.decision  \
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df=final_df[final_df['info.overs']==20]

# %%
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)

# %%
final_df
# Out:
#                                                 innings  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...
# 1     [{'1st innings': {'team': 'Australia', 'delive...
# 2     [{'1st innings': {'team': 'Australia', 'delive...
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...
# ...                                                 ...
# 1427  [{'1st innings': {'team': 'Sri Lanka', 'delive...
# 1428  [{'1st innings': {'team': 'Bangladesh', 'deliv...
# 1429  [{'1st innings': {'team': 'Netherlands', 'deli...
# 1430  [{'1st innings': {'team': 'Australia', 'delive...
# 1431  [{'1st innings': {'team': 'Sri Lanka', 'delive...
#
#                         info.dates  info.outcome.by.wickets  \
# 0     [datetime.date(2017, 2, 17)]                      5.0
# 1     [datetime.date(2017, 2, 19)]                      2.0
# 2     [datetime.date(2017, 2, 22)]                      NaN
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches=pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches.iloc[0]['innings']
# Out:
# "[{'1st innings': {'team': 'Australia', 'deliveries': [{0.1: {'batsman': 'AJ Finch', 'bowler': 'SL Malinga', 'non_striker': 'M Klinger', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}, {0.2: {'batsman': 'AJ Finch', 'bowler': 'SL Malinga', 'non_striker': 'M Klinger', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}, {0.3: {'batsman': 'AJ Finch', 'bowler': 'SL Malinga', 'non_striker': 'M Klinger', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}, {0.4: {'batsman': 'M Klinger', 'bowler': 'SL Malinga', 'non_striker': 'AJ Finch', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}, {0.5: {'batsman': 'M Klinger', 'bowler': 'SL Malinga', 'non_striker': 'AJ Finch', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}, {0.6: {'batsman': 'M Klinger', 'bowler': 'SL Malinga', 'non_striker': 'AJ Finch', 'runs': {'batsman': 3, 'extras': 0, 'total': 3}}}, {1.1: {'batsman': 'M Klinger', 'bowler': 'KMDN Kulasekara', 'non_striker': 'AJ Finch', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}, {1.2: {
# ...

# %%
# Out:
# 36122
